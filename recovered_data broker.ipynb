# %%
from databroker import DataBroker, get_events

# %%
db = DataBroker['d4f2ca40-fd6d-4cad-af87-40d53ddcfa29']

# %%
k = get_events(db)
for _ in k:
    print(_)
# Out:
# Event
# =====
# data            :
#   pgm_energy_i    : 501.1893455
#   sclr_ch6        : 3938.0
#   sclr_ch5        : 9621.0
#   pgm_energy_sp   : 501.0
#   sclr_ch2        : 10092.0
#   m1a_pit         : 0.3503772064
#   sclr_ch4        : 0.0
#   sclr_ch1        : 100000005.0
#   sclr_ch3        : 0.0
# seq_num         : 0
# time            : 1424357306.089052
# timestamps      :
#   pgm_energy_i    : 1424357305.935857
#   sclr_ch6        : 1424313341.612818
#   sclr_ch5        : 1424313341.612818
#   pgm_energy_sp   : 1424355435.916397
#   sclr_ch2        : 1424313341.612818
#   m1a_pit         : 1424357303.736789
#   sclr_ch4        : 1424313341.612818
#   sclr_ch1        : 1424313341.612818
#   sclr_ch3        : 1424313341.612818
# uid             : eeb890cd-8845-4dee-b4c0-9555dae56411
#
#   EventDescriptor
#   ---------------
#   +---------------+--------+-------+---------------------------------------+
# ...

# %%
dbs = DataBroker[-100:-130]

# %%
for d in db2:
    k = get_events(d)
    for _ in k:
        print(_)
# Out:
# Event
# =====
# data            :
#   diag6_flyer1    : 4646040.0
# seq_num         : 1
# time            : 1452199480.153399
# timestamps      :
#   diag6_flyer1    : 821046481.0272593
# uid             : 62d192da-1cd0-4d79-8775-362269228837
#
#   EventDescriptor
#   ---------------
#   +--------------+--------+-------+----------------------------------+
#   | data keys    | dtype  | shape |              source              |
#   +--------------+--------+-------+----------------------------------+
#   | diag6_flyer1 | number |  [2]  | XF:23ID1-BI{Diag:6-Cam:1}Stats1: |
#   +--------------+--------+-------+----------------------------------+
#   time            : 1452198475.4594212
#   uid             : 4533698e-e4f0-4254-a2f5-5993104c7cf5
#
#       RunStart
#       ````````
#       beamline_id     : CSX
#       config          :
#       group           :
#       owner           : xf23id1
#       project         : SAF 300177, Prop. 300369
#       sample          :
# ...
